# %% [markdown]
# # Notebook 03 — Trajectory Visualizer
# Overlays actual drawn paths onto the target shape path. Shows exactly where users deviate.

# %%
DATA_DIR    = "."
OUT_DIR     = "outputs"
CANVAS_SIZE = 500      # normalised 0-1 coords → pixels
TARGET_SHAPE = None    # set to e.g. "CIRCLE" to plot one shape only; None = all

import sys, os; sys.path.insert(0, os.path.dirname(os.path.abspath("hci_utils.py")))
from hci_utils import load_board_tries, save_fig, SHAPE_ORDER
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from scipy.interpolate import interp1d

df = load_board_tries(DATA_DIR)
shapes = [TARGET_SHAPE] if TARGET_SHAPE else [s for s in SHAPE_ORDER if s in df["shapeType"].values]
print(f"Will plot shapes: {shapes}")

# %% [markdown]
# ## Helper: interpolate path to N points

# %%
def path_to_array(coords):
    """Convert list of {x,y} dicts to Nx2 numpy array."""
    if not coords:
        return np.empty((0,2))
    return np.array([[p["x"], p["y"]] for p in coords])

def interpolate_path(pts, n=100):
    """Resample a path to exactly n evenly spaced points."""
    if len(pts) < 2:
        return pts
    dists = np.cumsum(np.r_[0, np.hypot(np.diff(pts[:,0]), np.diff(pts[:,1]))])
    if dists[-1] == 0:
        return pts
    t_new = np.linspace(0, dists[-1], n)
    fx = interp1d(dists, pts[:,0], kind="linear")
    fy = interp1d(dists, pts[:,1], kind="linear")
    return np.column_stack([fx(t_new), fy(t_new)])

N_INTERP = 100

# %% [markdown]
# ## Fig 03a — Trajectory overlay per shape

# %%
for shape in shapes:
    sub = df[df["shapeType"]==shape]
    if sub.empty:
        print(f"No data for {shape}"); continue

    fig, ax = plt.subplots(figsize=(5,5))

    # Target path (first try's bgCoordinates — same for all tries of this shape)
    bg = path_to_array(sub.iloc[0]["bgCoordinates"])
    if len(bg):
        ax.plot(bg[:,0]*CANVAS_SIZE, bg[:,1]*CANVAS_SIZE,
                color="black", lw=3, label="Target path", zorder=5)

    # Actual drawn paths
    for _, row in sub.iterrows():
        gc = path_to_array(row.get("gameCoordinates", []))
        if len(gc) < 2: continue
        color = "#2a6e4f" if row["completed"] else "#c84b2f"
        ax.plot(gc[:,0]*CANVAS_SIZE, gc[:,1]*CANVAS_SIZE,
                color=color, lw=1.2, alpha=0.45)

    from matplotlib.lines import Line2D
    legend_els = [
        Line2D([0],[0],color="black",lw=3,label="Target"),
        Line2D([0],[0],color="#2a6e4f",lw=2,alpha=0.7,label="Completed"),
        Line2D([0],[0],color="#c84b2f",lw=2,alpha=0.7,label="Not completed"),
    ]
    ax.legend(handles=legend_els, fontsize=8)
    ax.set_xlim(0, CANVAS_SIZE); ax.set_ylim(CANVAS_SIZE, 0)   # y flipped (screen coords)
    ax.set_aspect("equal"); ax.set_title(f"Trajectory overlay — {shape}", fontweight="bold")
    ax.axis("off")
    plt.tight_layout()
    save_fig(fig, f"fig03a_trajectory_overlay_{shape.lower()}.png", OUT_DIR)
    plt.show()

# %% [markdown]
# ## Fig 03b — Checkpoint deviation heatmap per shape

# %%
import matplotlib.cm as cm

for shape in shapes:
    sub = df[df["shapeType"]==shape]
    if sub.empty: continue

    bg = path_to_array(sub.iloc[0]["bgCoordinates"])
    if len(bg) < 2: continue
    bg_interp = interpolate_path(bg, N_INTERP)

    deviations = []
    for _, row in sub.iterrows():
        gc = path_to_array(row.get("gameCoordinates",[]))
        if len(gc) < 2: continue
        gc_interp = interpolate_path(gc, N_INTERP)
        dist = np.hypot(gc_interp[:,0]-bg_interp[:,0], gc_interp[:,1]-bg_interp[:,1])
        deviations.append(dist)

    if not deviations:
        print(f"No gameCoordinates for {shape}"); continue

    mean_dev = np.mean(deviations, axis=0)   # shape: (N_INTERP,)
    norm_dev = mean_dev / (mean_dev.max() + 1e-9)

    fig, ax = plt.subplots(figsize=(5,5))
    cmap_fn = cm.get_cmap("RdYlGn_r")
    for i in range(len(bg_interp)-1):
        ax.plot(
            [bg_interp[i,0]*CANVAS_SIZE, bg_interp[i+1,0]*CANVAS_SIZE],
            [bg_interp[i,1]*CANVAS_SIZE, bg_interp[i+1,1]*CANVAS_SIZE],
            color=cmap_fn(norm_dev[i]), lw=5, solid_capstyle="round"
        )
    sm = plt.cm.ScalarMappable(cmap="RdYlGn_r",
                                norm=plt.Normalize(mean_dev.min(), mean_dev.max()))
    sm.set_array([])
    plt.colorbar(sm, ax=ax, fraction=0.03, pad=0.02, label="Mean deviation (canvas units)")
    ax.set_xlim(0,CANVAS_SIZE); ax.set_ylim(CANVAS_SIZE,0)
    ax.set_aspect("equal"); ax.axis("off")
    ax.set_title(f"Checkpoint deviation — {shape}
(green=close, red=far)", fontweight="bold")
    plt.tight_layout()
    save_fig(fig, f"fig03b_checkpoint_deviation_{shape.lower()}.png", OUT_DIR)
    plt.show()

# %% [markdown]
# ## Fig 03c — Drawing speed along path

# %%
for shape in shapes:
    sub = df[df["shapeType"]==shape]
    has_ts = sub.apply(lambda r: any("timestamp" in p for p in r.get("gameCoordinates",[])), axis=1)
    sub_ts = sub[has_ts]
    if sub_ts.empty:
        print(f"No timestamp data for {shape}"); continue

    fig, ax = plt.subplots(figsize=(8,3))
    for _, row in sub_ts.iterrows():
        gc = row["gameCoordinates"]
        pts = np.array([[p["x"],p["y"],p["timestamp"]] for p in gc if "timestamp" in p])
        if len(pts)<2: continue
        dx = np.diff(pts[:,0]); dy = np.diff(pts[:,1]); dt = np.diff(pts[:,2])
        dt[dt==0] = 1e-9
        speed = np.hypot(dx,dy)/dt
        t_mid = (pts[:-1,2]+pts[1:,2])/2
        ax.plot(t_mid, speed, alpha=0.5, lw=1.5)
    ax.set_xlabel("Timestamp"); ax.set_ylabel("Speed (canvas units / timestamp unit)")
    ax.set_title(f"Drawing speed — {shape}", fontweight="bold")
    plt.tight_layout()
    save_fig(fig, f"fig03c_drawing_speed_{shape.lower()}.png", OUT_DIR)
    plt.show()
